# %% [markdown]
# # 🎢 Playground (연습장)
#
# 이곳은 자유롭게 코드를 작성하고 실험해보는 공간입니다.
# 새로운 문법을 테스트하거나, 헷갈리는 로직을 검증해 보세요.
#
# - `Shift + Enter`로 셀을 실행할 수 있습니다.
# - `B`를 눌러 아래에 새로운 셀을 추가할 수 있습니다.

# %%
print("=== Playground Start ===")

# 예: 문자열 슬라이싱 실험
text = "Hello Python"
print(f"Original: {text}")
print(f"Reverse: {text[::-1]}")
print(f"Slice [0:5]: {text[0:5]}")

# 예: 간단한 수식 실험
a, b = 10, 3
print(f"{a} // {b} = {a//b} (몫)")
print(f"{a} % {b} = {a%b} (나머지)")
